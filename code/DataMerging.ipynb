# %%
import pandas as pd

# %%
customer = pd.read_csv('customer.csv')
product = pd.read_csv('product.csv')
product_class = pd.read_csv('product_class.csv')
promotion = pd.read_csv('promotion.csv')
region = pd.read_csv('region.csv')
sales = pd.read_csv('sales.csv')
store = pd.read_csv('store.csv')
time_by_day = pd.read_csv('time_by_day.csv')

# %%
customer.head()
# Out:
#    customer_id  account_num      lname    fname   mi            address1  \
# 0            1  87462024688     Nowmer    Sheri   A.    2433 Bailey Road
# 1            2  87470586299    Whelply  Derrick   I.  2219 Dewing Avenue
# 2            3  87475757600      Derry   Jeanne  NaN     7640 First Ave.
# 3            4  87500482201     Spence  Michael   J.       337 Tosca Way
# 4            5  87514054179  Gutierrez     Maya  NaN     8668 Via Neruda
#
#   address2  address3  address4      city  ... gender  total_children  \
# 0      NaN       NaN       NaN  Tlaxiaco  ...      F               4
# 1      NaN       NaN       NaN     Sooke  ...      M               1
# 2      NaN       NaN       NaN  Issaquah  ...      F               1
# 3      NaN       NaN       NaN   Burnaby  ...      M               4
# 4      NaN       NaN       NaN    Novato  ...      F               3
#
#   num_children_at_home            education date_accnt_opened member_card  \
# 0                    2  Partial High School        1991-09-10      Bronze
# 1                    0  Partial High School        1993-03-11      Bronze
# 2                    1     Bachelors Degree        1991-06-11      Bronze
# 3                    4  Partial High School        1994-05-21      Normal
# 4                    0      Partial College        1992-08-21      Silver
#
#        occupation houseowner num_cars_owned         fullname
# 0  Skilled Manual          Y              4     Sheri Nowmer
# 1    Professional          N              3  Derrick Whelply
# 2    Professional          Y              2     Jeanne Derry
# 3  Skilled Manual          N              2   Michael Spence
# 4          Manual          N              3   Maya Gutierrez
#
# [5 rows x 29 columns]

# %%
customer.shape
# Out:
# (10281, 29)

# %%
customer.shape
customer.isna().sum()
# Out:
# customer_id                 0
# account_num                 0
# lname                       0
# fname                       0
# mi                       4333
# address1                    0
# address2                 9795
# address3                10281
# address4                10281
# city                        0
# state_province              0
# postal_code                 0
# country                     0
# customer_region_id          0
# phone1                      0
# phone2                      0
# birthdate                   0
# marital_status              0
# yearly_income               0
# gender                      0
# total_children              0
# num_children_at_home        0
# education                   0
# date_accnt_opened           0
# member_card                 0
# occupation                  0
# houseowner                  0
# num_cars_owned              0
# fullname                    0
# dtype: int64

# %%
# removing nominal columns with missing columns, 3 columns > 10% missing and 1 column > 4.3% missing
customer.drop(columns=['mi','address2','address3','address4'], inplace = True)
# dropping other nominal and ordinal columns that may not contribute to the analysis
customer.drop(columns=['account_num','lname','fname','fullname','address1','city','state_province','postal_code','country','customer_region_id','phone1','phone2','birthdate','date_accnt_opened'], inplace = True)

# %%
customer.shape
# Out:
# (10281, 11)

# %%
customer.head()
# Out:
#    customer_id marital_status yearly_income gender  total_children  \
# 0            1              M   $30K - $50K      F               4
# 1            2              S   $70K - $90K      M               1
# 2            3              M   $50K - $70K      F               1
# 3            4              M   $10K - $30K      M               4
# 4            5              S   $30K - $50K      F               3
#
#    num_children_at_home            education member_card      occupation  \
# 0                     2  Partial High School      Bronze  Skilled Manual
# 1                     0  Partial High School      Bronze    Professional
# 2                     1     Bachelors Degree      Bronze    Professional
# 3                     4  Partial High School      Normal  Skilled Manual
# 4                     0      Partial College      Silver          Manual
#
#   houseowner  num_cars_owned
# 0          Y               4
# 1          N               3
# 2          Y               2
# 3          N               2
# 4          N               3

# %%
customer.isna().sum()
# Out:
# customer_id             0
# marital_status          0
# yearly_income           0
# gender                  0
# total_children          0
# num_children_at_home    0
# education               0
# member_card             0
# occupation              0
# houseowner              0
# num_cars_owned          0
# dtype: int64

# %%
product.head()
# Out:
#    product_class_id  product_id  brand_name                 product_name  \
# 0                30           1  Washington       Washington Berry Juice
# 1                52           2  Washington       Washington Mango Drink
# 2                52           3  Washington  Washington Strawberry Drink
# 3                19           4  Washington        Washington Cream Soda
# 4                19           5  Washington         Washington Diet Soda
#
#            SKU   SRP  gross_weight  net_weight  recyclable_package  low_fat  \
# 0  90748583674  2.85          8.39        6.39                   0        0
# 1  96516502499  0.74          7.42        4.42                   0        1
# 2  58427771925  0.83         13.10       11.10                   1        1
# 3  64412155747  3.64         10.60        9.60                   1        0
# 4  85561191439  2.19          6.66        4.65                   1        0
#
#    units_per_case  cases_per_pallet  shelf_width  shelf_height  shelf_depth
# 0              30                14         16.9         12.60         7.40
# 1              18                 8         13.4          3.71        22.60
# 2              17                13         14.4         11.00         7.77
# 3              26                10         22.9         18.90         7.93
# 4               7                10         20.7         21.90        19.20

# %%
product.shape
# Out:
# (1560, 15)

# %%
product.isna().sum()
# Out:
# product_class_id      0
# product_id            0
# brand_name            0
# product_name          0
# SKU                   0
# SRP                   0
# gross_weight          0
# net_weight            0
# recyclable_package    0
# low_fat               0
# units_per_case        0
# cases_per_pallet      0
# shelf_width           0
# shelf_height          0
# shelf_depth           0
# dtype: int64

# %%
# dropping few columns that are not relevant
product.drop(columns=['SKU','product_name','cases_per_pallet','shelf_width','shelf_height','shelf_depth'], inplace = True)

# %%
product.head()
# Out:
#    product_class_id  product_id  brand_name   SRP  gross_weight  net_weight  \
# 0                30           1  Washington  2.85          8.39        6.39
# 1                52           2  Washington  0.74          7.42        4.42
# 2                52           3  Washington  0.83         13.10       11.10
# 3                19           4  Washington  3.64         10.60        9.60
# 4                19           5  Washington  2.19          6.66        4.65
#
#    recyclable_package  low_fat  units_per_case
# 0                   0        0              30
# 1                   0        1              18
# 2                   1        1              17
# 3                   1        0              26
# 4                   1        0               7

# %%
product.shape
# Out:
# (1560, 9)

# %%
product_class.head()
# Out:
#    product_class_id   subcategory       category       department family
# 0                 1          Nuts      Specialty          Produce   Food
# 1                 2     Shellfish        Seafood          Seafood   Food
# 2                 3  Canned Fruit          Fruit  Canned Products   Food
# 3                 4        Spices   Baking Goods     Baking Goods   Food
# 4                 5         Pasta  Starchy Foods    Starchy Foods   Food

# %%
product_class.shape
# Out:
# (110, 5)

# %%
product_class.isna().sum()
# Out:
# product_class_id    0
# subcategory         0
# category            0
# department          0
# family              0
# dtype: int64

# %%
# dropping the subcategory column as the division. becomes too granular
product_class.drop(columns=['subcategory'], inplace = True)

# %%
# lets combine two tables, product and product_class
product_and_class = pd.merge(product, product_class, on = 'product_class_id', how = 'inner')

# %%
product_and_class.isna().sum()
# Out:
# product_class_id      0
# product_id            0
# brand_name            0
# SRP                   0
# gross_weight          0
# net_weight            0
# recyclable_package    0
# low_fat               0
# units_per_case        0
# category              0
# department            0
# family                0
# dtype: int64

# %%
product_and_class.shape
# Out:
# (1560, 12)

# %%
# lets drop product class id column as it is no longer required
product_and_class.drop(columns=['product_class_id'], inplace=True)

# %%
product_and_class.head()
# Out:
#    product_id  brand_name   SRP  gross_weight  net_weight  recyclable_package  \
# 0           1  Washington  2.85          8.39        6.39                   0
# 1           8  Washington  2.59          8.97        6.97                   1
# 2           9  Washington  2.42          7.14        5.13                   0
# 3          10  Washington  1.42          8.13        7.13                   1
# 4         312   Excellent  2.13         12.60       10.60                   1
#
#    low_fat  units_per_case              category department family
# 0        0              30  Pure Juice Beverages  Beverages  Drink
# 1        0              27  Pure Juice Beverages  Beverages  Drink
# 2        0              34  Pure Juice Beverages  Beverages  Drink
# 3        0              28  Pure Juice Beverages  Beverages  Drink
# 4        0               2  Pure Juice Beverages  Beverages  Drink

# %%
product_and_class.shape
# Out:
# (1560, 11)

# %%
promotion.head()
# Out:
#    promotion_id  promotion_district_id       promotion_name  \
# 0             1                    110  High Roller Savings
# 1             2                    110  Green Light Special
# 2             3                    110        Wallet Savers
# 3             4                    110     Weekend Markdown
# 4             5                    110         Bag Stuffers
#
#             media_type     cost  start_date    end_date
# 0   Product Attachment  14435.0  1996-01-03  1996-01-06
# 1   Product Attachment   8907.0  1996-01-18  1996-01-20
# 2                Radio  12512.0  1996-02-02  1996-02-05
# 3      In-Store Coupon  11256.0  1996-02-13  1996-02-15
# 4  Sunday Paper, Radio  12275.0  1996-02-28  1996-03-01

# %%
promotion.shape
# Out:
# (1863, 7)

# %%
promotion.isna().sum()
# Out:
# promotion_id             0
# promotion_district_id    0
# promotion_name           0
# media_type               0
# cost                     0
# start_date               0
# end_date                 0
# dtype: int64

# %%
# droppping some ordinal and nominal columns in promotion table
promotion.drop(columns=['promotion_district_id','start_date','end_date'], inplace=True)

# %%
promotion.shape
# Out:
# (1863, 4)

# %%
promotion.head()
# Out:
#    promotion_id       promotion_name           media_type     cost
# 0             1  High Roller Savings   Product Attachment  14435.0
# 1             2  Green Light Special   Product Attachment   8907.0
# 2             3        Wallet Savers                Radio  12512.0
# 3             4     Weekend Markdown      In-Store Coupon  11256.0
# 4             5         Bag Stuffers  Sunday Paper, Radio  12275.0

# %%
region.head()
# Out:
#    region_id     sales_city sales_state_province sales_district  \
# 0          0           None                 None    No District
# 1          1  San Francisco                   CA  San Francisco
# 2          2    Mexico City                   DF    Mexico City
# 3          3    Los Angeles                   CA    Los Angeles
# 4          4    Guadalajara              Jalisco    Guadalajara
#
#      sales_region sales_country  sales_district_id
# 0       No Region    No Country                  0
# 1    Central West           USA                123
# 2  Mexico Central        Mexico                118
# 3      South West           USA                116
# 4     Mexico West        Mexico                114

# %%
region.shape
# Out:
# (110, 7)

# %%
region.isna().sum()
# Out:
# region_id               0
# sales_city              0
# sales_state_province    0
# sales_district          0
# sales_region            0
# sales_country           0
# sales_district_id       0
# dtype: int64

# %%
# dropping few nominal columns as they are not relevant
region.drop(columns=['sales_city','sales_state_province','sales_district','sales_region','sales_district_id'], inplace=True)

# %%
region.head()
# Out:
#    region_id sales_country
# 0          0    No Country
# 1          1           USA
# 2          2        Mexico
# 3          3           USA
# 4          4        Mexico

# %%
# sales table is the transaction/fact table in out case and it will be merged with other dimension tables
sales.head()
# Out:
#    product_id  time_id  customer_id  promotion_id  store_id  store_sales  \
# 0         337      371         6280           NaN         2         1.50
# 1        1512      371         6280           NaN         2         1.62
# 2         963      371         4018           NaN         2         2.40
# 3         181      371         4018           NaN         2         2.79
# 4        1383      371         4018           NaN         2         5.18
#
#    store_cost  unit_sales
# 0      0.5100           2
# 1      0.6318           3
# 2      0.7200           1
# 3      1.0323           3
# 4      2.1756           2

# %%
sales.shape
# Out:
# (269720, 8)

# %%
sales.isna().sum()
# Out:
# product_id           0
# time_id              0
# customer_id          0
# promotion_id    198969
# store_id             0
# store_sales          0
# store_cost           0
# unit_sales           0
# dtype: int64

# %%
# a row which does not map to promotion is not useful as we are concerned on the promotions
print(sales.shape[0] - sales['promotion_id'].isna().sum())
# Out:
# 70751

# %%
sales.dropna(inplace=True)

# %%
sales.shape[0]
# Out:
# 70751

# %%
store.head()
# Out:
#    store_id           store_type  region_id store_name  store_number  \
# 0         0         HeadQuarters          0         HQ             0
# 1         1          Supermarket         28    Store 1             1
# 2         2        Small Grocery         78    Store 2             2
# 3         3          Supermarket         76    Store 3             3
# 4         4  Gourmet Supermarket         27    Store 4             4
#
#   store_street_address  store_city store_state  store_postal_code  \
# 0        1 Alameda Way     Alameda          CA              55555
# 1       2853 Bailey Rd    Acapulco    Guerrero              55555
# 2   5203 Catanzaro Way  Bellingham          WA              55555
# 3   1501 Ramsey Circle   Bremerton          WA              55555
# 4     433 St George Dr     Camacho   Zacatecas              55555
#
#   store_country  ...    last_remodel_date store_sqft grocery_sqft frozen_sqft  \
# 0           USA  ...                  NaN        NaN          NaN         NaN
# 1        Mexico  ...  1990-12-05 00:00:00    23593.0      17475.0      3671.0
# 2           USA  ...  1973-06-04 00:00:00    28206.0      22271.0      3561.0
# 3           USA  ...  1967-11-19 00:00:00    39696.0      24390.0      9184.0
# 4        Mexico  ...  1995-12-01 00:00:00    23759.0      16844.0      4149.0
#
#   meat_sqft  coffee_bar  video_store  salad_bar  prepared_food  florist
# 0       NaN           0            0          0              0        0
# 1    2447.0           0            0          0              0        0
# 2    2374.0           1            0          0              0        0
# 3    6122.0           0            0          1              1        0
# 4    2766.0           1            0          1              1        1
#
# [5 rows x 24 columns]

# %%
store.shape
# Out:
# (25, 14)

# %%
store.isna().sum()
# Out:
# store_id                0
# store_type              0
# region_id               0
# store_name              0
# store_number            0
# store_street_address    0
# store_city              0
# store_state             0
# store_postal_code       0
# store_country           0
# store_manager           1
# store_phone             1
# store_fax               1
# first_opened_date       1
# last_remodel_date       1
# store_sqft              5
# grocery_sqft            5
# frozen_sqft             5
# meat_sqft               5
# coffee_bar              0
# video_store             0
# salad_bar               0
# prepared_food           0
# florist                 0
# dtype: int64

# %%
# since there are only 25 rows in store table, we cannot drop the missing row columns
# first lets impute numerical columns by their medians since they are not affected by outliers

store['store_sqft'] = store['store_sqft'].fillna(store['store_sqft'].median())
store['grocery_sqft'] = store['grocery_sqft'].fillna(store['grocery_sqft'].median())
store['frozen_sqft'] = store['frozen_sqft'].fillna(store['frozen_sqft'].median())
store['meat_sqft'] = store['meat_sqft'].fillna(store['meat_sqft'].median())

# %%
# lets impute categorical variables using mode
store['store_manager'] = store['store_manager'].fillna(store['store_manager'].mode())
store['store_phone'] = store['store_phone'].fillna(store['store_phone'].mode())
store['store_fax'] = store['store_fax'].fillna(store['store_fax'].mode())

# %%
store['first_opened_date'] = store['first_opened_date'].fillna(store['first_opened_date'].mode())
store['last_remodel_date'] = store['last_remodel_date'].fillna(store['last_remodel_date'].mode())

# %%
store.isna().sum()
# Out:
# store_id                0
# store_type              0
# region_id               0
# store_name              0
# store_number            0
# store_street_address    0
# store_city              0
# store_state             0
# store_postal_code       0
# store_country           0
# store_manager           0
# store_phone             0
# store_fax               0
# first_opened_date       0
# last_remodel_date       0
# store_sqft              0
# grocery_sqft            0
# frozen_sqft             0
# meat_sqft               0
# coffee_bar              0
# video_store             0
# salad_bar               0
# prepared_food           0
# florist                 0
# dtype: int64

# %%
# lets drop few ordinal and nominal columns that are not required for our analysis
store.drop(columns=['store_name','store_number','store_street_address','store_postal_code','store_country','store_manager','store_phone','store_fax','first_opened_date','last_remodel_date'], inplace=True)

# %%
store.head()
# Out:
#    store_id           store_type  region_id  store_city store_state  \
# 0         0         HeadQuarters          0     Alameda          CA
# 1         1          Supermarket         28    Acapulco    Guerrero
# 2         2        Small Grocery         78  Bellingham          WA
# 3         3          Supermarket         76   Bremerton          WA
# 4         4  Gourmet Supermarket         27     Camacho   Zacatecas
#
#    store_sqft  grocery_sqft  frozen_sqft  meat_sqft  coffee_bar  video_store  \
# 0     27950.0       19405.5       4967.0     3311.0           0            0
# 1     23593.0       17475.0       3671.0     2447.0           0            0
# 2     28206.0       22271.0       3561.0     2374.0           1            0
# 3     39696.0       24390.0       9184.0     6122.0           0            0
# 4     23759.0       16844.0       4149.0     2766.0           1            0
#
#    salad_bar  prepared_food  florist
# 0          0              0        0
# 1          0              0        0
# 2          0              0        0
# 3          1              1        0
# 4          1              1        1

# %%
# lets combine store and region tables since region Id is present in store table and store Id is present in sales table
store_and_region = pd.merge(store, region, on = 'region_id', how = 'inner')

# %%
store_and_region.drop(columns=['region_id'],inplace=True)

# %%
store_and_region.head()
# Out:
#    store_id           store_type  store_city store_state  store_sqft  \
# 0         0         HeadQuarters     Alameda          CA     27950.0
# 1         1          Supermarket    Acapulco    Guerrero     23593.0
# 2         2        Small Grocery  Bellingham          WA     28206.0
# 3         3          Supermarket   Bremerton          WA     39696.0
# 4         4  Gourmet Supermarket     Camacho   Zacatecas     23759.0
#
#    grocery_sqft  frozen_sqft  meat_sqft  coffee_bar  video_store  salad_bar  \
# 0       19405.5       4967.0     3311.0           0            0          0
# 1       17475.0       3671.0     2447.0           0            0          0
# 2       22271.0       3561.0     2374.0           1            0          0
# 3       24390.0       9184.0     6122.0           0            0          1
# 4       16844.0       4149.0     2766.0           1            0          1
#
#    prepared_food  florist sales_country
# 0              0        0    No Country
# 1              0        0        Mexico
# 2              0        0           USA
# 3              1        0           USA
# 4              1        1        Mexico

# %%
store_and_region.isna().sum()
# Out:
# store_id         0
# store_type       0
# store_city       0
# store_state      0
# store_sqft       0
# grocery_sqft     0
# frozen_sqft      0
# meat_sqft        0
# coffee_bar       0
# video_store      0
# salad_bar        0
# prepared_food    0
# florist          0
# sales_country    0
# dtype: int64

# %%
store_and_region.shape
# Out:
# (25, 14)

# %%
time_by_day.head()
# Out:
#    time_id    the_date    the_day  the_year  the_month  day_of_month
# 0        1  1996-01-01     Monday      1996          1             1
# 1        2  1996-01-02    Tuesday      1996          1             2
# 2        3  1996-01-03  Wednesday      1996          1             3
# 3        4  1996-01-04   Thursday      1996          1             4
# 4        5  1996-01-05     Friday      1996          1             5

# %%
time_by_day.isna().sum()
# Out:
# time_id         0
# the_date        0
# the_day         0
# the_year        0
# the_month       0
# day_of_month    0
# dtype: int64

# %%
# sales table is the transaction table in out case and it will be merged with other dimension tables
sales.head()
# Out:
#     product_id  time_id  customer_id  promotion_id  store_id  store_sales  \
# 58         842      395         8178         108.0         2         6.40
# 59        1364      395         8178         108.0         2         3.20
# 60         942      395         8178         108.0         2         4.68
# 61        1064      395         8178         108.0         2         1.08
# 62         282      395         8178         108.0         2         0.93
#
#     store_cost  unit_sales
# 58      2.1120           2
# 59      1.5680           2
# 60      1.8252           2
# 61      0.3240           2
# 62      0.3999           1

# %%
# first lets merge sales with product table
sales_product = pd.merge(sales, product_and_class, on = 'product_id', how = 'inner')
sales_product
# Out:
#        product_id  time_id  customer_id  promotion_id  store_id  store_sales  \
# 0             842      395         8178         108.0         2         6.40
# 1             842      411         4417         188.0         3         9.60
# 2             842      469         1427         508.0         6         9.60
# 3             842      538         4433         513.0         6         9.60
# 4             842      579         8445         516.0         7         6.40
# ...           ...      ...          ...           ...       ...          ...
# 70746         253      956         5391         701.0        21         3.56
# 70747         253      999         6971         704.0        21         2.67
# 70748         253      984         6461         703.0        21         3.56
# 70749         253     1082         3949         710.0        21         3.56
# 70750         253     1082           57         710.0        21         4.45
#
#        store_cost  unit_sales brand_name   SRP  gross_weight  net_weight  \
# 0          2.1120           2  Nationeel  3.20          18.9        16.8
# 1          4.4160           3  Nationeel  3.20          18.9        16.8
# 2          3.1680           3  Nationeel  3.20          18.9        16.8
# 3          4.1280           3  Nationeel  3.20          18.9        16.8
# 4          2.8800           2  Nationeel  3.20          18.9        16.8
# ...           ...         ...        ...   ...           ...         ...
# 70746      1.5664           4     Choice  0.89          18.2        15.2
# 70747      1.2015           3     Choice  0.89          18.2        15.2
# 70748      1.1392           4     Choice  0.89          18.2        15.2
# 70749      1.2460           4     Choice  0.89          18.2        15.2
# 70750      1.6020           5     Choice  0.89          18.2        15.2
#
#        recyclable_package  low_fat  units_per_case     category   department  \
# 0                       1        0              33  Snack Foods  Snack Foods
# 1                       1        0              33  Snack Foods  Snack Foods
# 2                       1        0              33  Snack Foods  Snack Foods
# 3                       1        0              33  Snack Foods  Snack Foods
# 4                       1        0              33  Snack Foods  Snack Foods
# ...                   ...      ...             ...          ...          ...
# 70746                   0        1              34        Candy       Snacks
# 70747                   0        1              34        Candy       Snacks
# 70748                   0        1              34        Candy       Snacks
# 70749                   0        1              34        Candy       Snacks
# 70750                   0        1              34        Candy       Snacks
#
#       family
# 0       Food
# 1       Food
# 2       Food
# 3       Food
# 4       Food
# ...      ...
# 70746   Food
# 70747   Food
# 70748   Food
# 70749   Food
# 70750   Food
#
# [70751 rows x 18 columns]

# %%
sales_product.isna().sum()
# Out:
# product_id            0
# time_id               0
# customer_id           0
# promotion_id          0
# store_id              0
# store_sales           0
# store_cost            0
# unit_sales            0
# brand_name            0
# SRP                   0
# gross_weight          0
# net_weight            0
# recyclable_package    0
# low_fat               0
# units_per_case        0
# category              0
# department            0
# family                0
# dtype: int64

# %%
sales.shape[0]-sales_product.shape[0]
# Out:
# 0

# %%
# lets merge sales_product dataframe with promotion dataframe
sales_prod_promo = pd.merge(sales_product, promotion, on = 'promotion_id', how = 'inner')

# %%
sales_product.shape[0]-sales_prod_promo.shape[0]
# Out:
# 0

# %%
sales_prod_promo.isna().sum()
# Out:
# product_id            0
# time_id               0
# customer_id           0
# promotion_id          0
# store_id              0
# store_sales           0
# store_cost            0
# unit_sales            0
# brand_name            0
# SRP                   0
# gross_weight          0
# net_weight            0
# recyclable_package    0
# low_fat               0
# units_per_case        0
# category              0
# department            0
# family                0
# promotion_name        0
# media_type            0
# cost                  0
# dtype: int64

# %%
sales_prod_promo.head()
# Out:
#    product_id  time_id  customer_id  promotion_id  store_id  store_sales  \
# 0         842      395         8178         108.0         2         6.40
# 1        1364      395         8178         108.0         2         3.20
# 2         942      395         8178         108.0         2         4.68
# 3        1064      395         8178         108.0         2         1.08
# 4         282      395         8178         108.0         2         0.93
#
#    store_cost  unit_sales brand_name   SRP  ...  net_weight  \
# 0      2.1120           2  Nationeel  3.20  ...        16.8
# 1      1.5680           2    Hilltop  1.60  ...        17.7
# 2      1.8252           2   Fabulous  2.34  ...        14.7
# 3      0.3240           2  Bird Call  0.54  ...        16.2
# 4      0.3999           1      Great  0.93  ...        11.6
#
#    recyclable_package  low_fat  units_per_case              category  \
# 0                   1        0              33           Snack Foods
# 1                   1        0              29               Hygiene
# 2                   0        0              13  Carbonated Beverages
# 3                   1        0              15         Decongestants
# 4                   1        0              30                 Bread
#
#            department          family promotion_name media_type    cost
# 0         Snack Foods            Food      Go For It      Radio  7302.0
# 1  Health and Hygiene  Non-Consumable      Go For It      Radio  7302.0
# 2           Beverages           Drink      Go For It      Radio  7302.0
# 3  Health and Hygiene  Non-Consumable      Go For It      Radio  7302.0
# 4         Baked Goods            Food      Go For It      Radio  7302.0
#
# [5 rows x 21 columns]

# %%
# lets merge sales_prod_promo dataframe with store_and_region dataframe
sales_prod_promo_store = pd.merge(sales_prod_promo, store_and_region, on = 'store_id', how = 'inner')

# %%
sales_prod_promo_store.isna().sum()
# Out:
# product_id            0
# time_id               0
# customer_id           0
# promotion_id          0
# store_id              0
# store_sales           0
# store_cost            0
# unit_sales            0
# brand_name            0
# SRP                   0
# gross_weight          0
# net_weight            0
# recyclable_package    0
# low_fat               0
# units_per_case        0
# category              0
# department            0
# family                0
# promotion_name        0
# media_type            0
# cost                  0
# store_type            0
# store_city            0
# store_state           0
# store_sqft            0
# grocery_sqft          0
# frozen_sqft           0
# meat_sqft             0
# coffee_bar            0
# video_store           0
# salad_bar             0
# prepared_food         0
# florist               0
# sales_country         0
# dtype: int64

# %%
sales_prod_promo.shape[0]-sales_prod_promo_store.shape[0]
# Out:
# 0

# %%
sales_prod_promo_store.head()
# Out:
#    product_id  time_id  customer_id  promotion_id  store_id  store_sales  \
# 0         842      395         8178         108.0         2         6.40
# 1        1364      395         8178         108.0         2         3.20
# 2         942      395         8178         108.0         2         4.68
# 3        1064      395         8178         108.0         2         1.08
# 4         282      395         8178         108.0         2         0.93
#
#    store_cost  unit_sales brand_name   SRP  ...  store_sqft  grocery_sqft  \
# 0      2.1120           2  Nationeel  3.20  ...     28206.0       22271.0
# 1      1.5680           2    Hilltop  1.60  ...     28206.0       22271.0
# 2      1.8252           2   Fabulous  2.34  ...     28206.0       22271.0
# 3      0.3240           2  Bird Call  0.54  ...     28206.0       22271.0
# 4      0.3999           1      Great  0.93  ...     28206.0       22271.0
#
#    frozen_sqft  meat_sqft  coffee_bar video_store salad_bar prepared_food  \
# 0       3561.0     2374.0           1           0         0             0
# 1       3561.0     2374.0           1           0         0             0
# 2       3561.0     2374.0           1           0         0             0
# 3       3561.0     2374.0           1           0         0             0
# 4       3561.0     2374.0           1           0         0             0
#
#   florist sales_country
# 0       0           USA
# 1       0           USA
# 2       0           USA
# 3       0           USA
# 4       0           USA
#
# [5 rows x 34 columns]

# %%
sales_prod_promo_store.shape
# Out:
# (70751, 34)

# %%
# lets merge sales_prod_promo_store dataframe with store_and_region dataframe
sales_prod_promo_store_cust = pd.merge(sales_prod_promo_store, customer, on = 'customer_id', how = 'inner')

# %%
sales_prod_promo_store_cust.shape
# Out:
# (70751, 44)

# %%
sales_prod_promo_store_cust.isna().sum()
# Out:
# product_id              0
# time_id                 0
# customer_id             0
# promotion_id            0
# store_id                0
# store_sales             0
# store_cost              0
# unit_sales              0
# brand_name              0
# SRP                     0
# gross_weight            0
# net_weight              0
# recyclable_package      0
# low_fat                 0
# units_per_case          0
# category                0
# department              0
# family                  0
# promotion_name          0
# media_type              0
# cost                    0
# store_type              0
# store_city              0
# store_state             0
# store_sqft              0
# grocery_sqft            0
# frozen_sqft             0
# meat_sqft               0
# coffee_bar              0
# video_store             0
# salad_bar               0
# prepared_food           0
# florist                 0
# sales_country           0
# marital_status          0
# yearly_income           0
# gender                  0
# total_children          0
# num_children_at_home    0
# education               0
# member_card             0
# occupation              0
# houseowner              0
# num_cars_owned          0
# dtype: int64

# %%
sales_prod_promo_store_cust[['customer_id','promotion_id','promotion_name','cost']]
# Out:
#        customer_id  promotion_id       promotion_name    cost
# 0             8178         108.0            Go For It  7302.0
# 1             8178         108.0            Go For It  7302.0
# 2             8178         108.0            Go For It  7302.0
# 3             8178         108.0            Go For It  7302.0
# 4             8178         108.0            Go For It  7302.0
# ...            ...           ...                  ...     ...
# 70746         4605         388.0  Super Wallet Savers  6915.0
# 70747         4605         388.0  Super Wallet Savers  6915.0
# 70748         1011         388.0  Super Wallet Savers  6915.0
# 70749         6004         388.0  Super Wallet Savers  6915.0
# 70750         6004         388.0  Super Wallet Savers  6915.0
#
# [70751 rows x 4 columns]

# %%
unique_combinations1 = sales_prod_promo_store_cust[['promotion_id','customer_id','cost']]

# %%
unique_combinations1.groupby(['promotion_id'])['customer_id'].count()
# Out:
# promotion_id
# 54.0      174
# 55.0      170
# 58.0      183
# 59.0      161
# 62.0      152
#          ...
# 1882.0    173
# 1888.0    172
# 1890.0    130
# 1892.0    204
# 1893.0    195
# Name: customer_id, Length: 405, dtype: int64

# %%
import copy
test = copy.copy(unique_combinations1[['promotion_id','cost']].drop_duplicates().sort_index())

# %%
test
# Out:
#        promotion_id     cost
# 0             108.0   7302.0
# 23            114.0  12180.0
# 28            149.0  13290.0
# 34            122.0   7913.0
# 51            139.0  10802.0
# ...             ...      ...
# 70457         375.0   9661.0
# 70483         387.0  10827.0
# 70515         382.0   8411.0
# 70519         393.0  12379.0
# 70609         377.0  13120.0
#
# [405 rows x 2 columns]

# %%
test.isna().sum()
# Out:
# promotion_id    0
# cost            0
# dtype: int64

# %%
test2 = unique_combinations1.groupby("promotion_id")['customer_id'].count().reset_index()

# %%
test2 = test2.rename(columns={'customer_id': 'customer_count'})

# %%
test2.isna().sum()
# Out:
# promotion_id      0
# customer_count    0
# dtype: int64

# %%
test2
# Out:
#      promotion_id  customer_count
# 0            54.0             174
# 1            55.0             170
# 2            58.0             183
# 3            59.0             161
# 4            62.0             152
# ..            ...             ...
# 400        1882.0             173
# 401        1888.0             172
# 402        1890.0             130
# 403        1892.0             204
# 404        1893.0             195
#
# [405 rows x 2 columns]

# %%
test3 = pd.merge(test, test2, left_on='promotion_id', right_on='promotion_id', how='inner')

# %%
test3.head()
# Out:
#    promotion_id     cost  customer_count
# 0         108.0   7302.0              32
# 1         114.0  12180.0              48
# 2         149.0  13290.0              30
# 3         122.0   7913.0              15
# 4         139.0  10802.0              52

# %%
test3.isna().sum()
# Out:
# promotion_id      0
# cost              0
# customer_count    0
# dtype: int64

# %%
# test3 table shows the promotion, its total cost, targeted customer count and cost per customer
test3['cost_per_customer'] = test3['cost']/test3['customer_count']
test3
# Out:
#      promotion_id     cost  customer_count  cost_per_customer
# 0           108.0   7302.0              32         228.187500
# 1           114.0  12180.0              48         253.750000
# 2           149.0  13290.0              30         443.000000
# 3           122.0   7913.0              15         527.533333
# 4           139.0  10802.0              52         207.730769
# ..            ...      ...             ...                ...
# 400         375.0   9661.0              31         311.645161
# 401         387.0  10827.0              16         676.687500
# 402         382.0   8411.0              10         841.100000
# 403         393.0  12379.0              35         353.685714
# 404         377.0  13120.0              18         728.888889
#
# [405 rows x 4 columns]

# %%
test3.drop(columns=['cost','customer_count'],inplace=True)

# %%
customer_acq_cost = pd.merge(sales_prod_promo_store_cust, test3, on='promotion_id', how='inner')

# %%
# lets drop the nominal id columns
customer_acq_cost.drop(columns=['product_id','time_id','customer_id','promotion_id','store_id','cost'], inplace=True)

# %%
customer_acq_cost
# Out:
#        store_sales  store_cost  unit_sales brand_name   SRP  gross_weight  \
# 0             6.40      2.1120           2  Nationeel  3.20          18.9
# 1             3.20      1.5680           2    Hilltop  1.60          19.8
# 2             4.68      1.8252           2   Fabulous  2.34          17.7
# 3             1.08      0.3240           2  Bird Call  0.54          17.3
# 4             0.93      0.3999           1      Great  0.93          13.6
# ...            ...         ...         ...        ...   ...           ...
# 70746         4.53      1.5402           3    PigTail  1.51          12.5
# 70747         2.66      1.2768           2  Landslide  1.33          21.9
# 70748         2.86      1.4014           2   High Top  1.43          21.9
# 70749         1.66      0.6640           2     Sunset  0.83          21.0
# 70750         1.48      0.6512           2  Tri-State  0.74          15.2
#
#        net_weight  recyclable_package  low_fat  units_per_case  ...  \
# 0            16.8                   1        0              33  ...
# 1            17.7                   1        0              29  ...
# 2            14.7                   0        0              13  ...
# 3            16.2                   1        0              15  ...
# 4            11.6                   1        0              30  ...
# ...           ...                 ...      ...             ...  ...
# 70746        10.5                   1        1              27  ...
# 70747        19.8                   1        1              13  ...
# 70748        20.8                   0        0              13  ...
# 70749        18.0                   0        0               2  ...
# 70750        14.1                   1        0              30  ...
#
#       yearly_income gender total_children num_children_at_home  \
# 0       $50K - $70K      F              3                    0
# 1       $50K - $70K      F              3                    0
# 2       $50K - $70K      F              3                    0
# 3       $50K - $70K      F              3                    0
# 4       $50K - $70K      F              3                    0
# ...             ...    ...            ...                  ...
# 70746   $50K - $70K      M              4                    0
# 70747   $50K - $70K      M              4                    0
# 70748   $30K - $50K      F              0                    0
# 70749   $30K - $50K      F              0                    0
# 70750   $30K - $50K      F              0                    0
#
#                 education member_card    occupation houseowner  \
# 0        Bachelors Degree      Golden    Management          Y
# 1        Bachelors Degree      Golden    Management          Y
# 2        Bachelors Degree      Golden    Management          Y
# 3        Bachelors Degree      Golden    Management          Y
# 4        Bachelors Degree      Golden    Management          Y
# ...                   ...         ...           ...        ...
# 70746    Bachelors Degree      Bronze  Professional          N
# 70747    Bachelors Degree      Bronze  Professional          N
# 70748  High School Degree      Bronze        Manual          Y
# 70749  High School Degree      Bronze        Manual          Y
# 70750  High School Degree      Bronze        Manual          Y
#
#        num_cars_owned  cost_per_customer
# 0                   3         228.187500
# 1                   3         228.187500
# 2                   3         228.187500
# 3                   3         228.187500
# 4                   3         228.187500
# ...               ...                ...
# 70746               3         728.888889
# 70747               3         728.888889
# 70748               3         728.888889
# 70749               3         728.888889
# 70750               3         728.888889
#
# [70751 rows x 39 columns]

# %%
customer_acq_cost['cost_per_customer'] = customer_acq_cost['cost_per_customer'].astype(float).round(2)

# %%
customer_acq_cost = customer_acq_cost.rename(columns={'store_sales':'store_sales(in millions)','store_cost':'store_cost(in millions)','unit_sales':'unit_sales(in millions)','category':'food_category',\
                                                      'department':'food_department','family':'food_family','cost_per_customer':'cost'})

# %%
customer_acq_cost.columns
# Out:
# Index(['store_sales(in millions)', 'store_cost(in millions)',
#        'unit_sales(in millions)', 'brand_name', 'SRP', 'gross_weight',
#        'net_weight', 'recyclable_package', 'low_fat', 'units_per_case',
#        'food_category', 'food_department', 'food_family', 'promotion_name',
#        'media_type', 'store_type', 'store_city', 'store_state', 'store_sqft',
#        'grocery_sqft', 'frozen_sqft', 'meat_sqft', 'coffee_bar', 'video_store',
#        'salad_bar', 'prepared_food', 'florist', 'sales_country',
#        'marital_status', 'yearly_income', 'gender', 'total_children',
#        'num_children_at_home', 'education', 'member_card', 'occupation',
#        'houseowner', 'num_cars_owned', 'cost'],
#       dtype='object')

# %%
new_order = ['food_category', 'food_department', 'food_family','store_sales(in millions)', 'store_cost(in millions)', 'unit_sales(in millions)', 'promotion_name', 'sales_country',\
             'marital_status', 'gender', 'total_children', 'education', 'member_card', 'occupation', 'houseowner', 'num_cars_owned', 'yearly_income', 'num_children_at_home',\
             'brand_name', 'SRP', 'gross_weight', 'net_weight', 'recyclable_package', 'low_fat', 'units_per_case', 'store_type', 'store_city', 'store_state', 'store_sqft', 'grocery_sqft',\
             'frozen_sqft', 'meat_sqft', 'coffee_bar', 'video_store', 'salad_bar', 'prepared_food', 'florist', 'media_type', 'cost']
CAC = customer_acq_cost[new_order]

# %%
CAC
# Out:
#               food_category     food_department     food_family  \
# 0               Snack Foods         Snack Foods            Food
# 1                   Hygiene  Health and Hygiene  Non-Consumable
# 2      Carbonated Beverages           Beverages           Drink
# 3             Decongestants  Health and Hygiene  Non-Consumable
# 4                     Bread         Baked Goods            Food
# ...                     ...                 ...             ...
# 70746                  Meat        Frozen Foods            Food
# 70747      Jams and Jellies        Baking Goods            Food
# 70748            Vegetables             Produce            Food
# 70749     Cleaning Supplies           Household  Non-Consumable
# 70750            Vegetables             Produce            Food
#
#        store_sales(in millions)  store_cost(in millions)  \
# 0                          6.40                   2.1120
# 1                          3.20                   1.5680
# 2                          4.68                   1.8252
# 3                          1.08                   0.3240
# 4                          0.93                   0.3999
# ...                         ...                      ...
# 70746                      4.53                   1.5402
# 70747                      2.66                   1.2768
# 70748                      2.86                   1.4014
# 70749                      1.66                   0.6640
# 70750                      1.48                   0.6512
#
#        unit_sales(in millions) promotion_name sales_country marital_status  \
# 0                            2      Go For It           USA              M
# 1                            2      Go For It           USA              M
# 2                            2      Go For It           USA              M
# 3                            2      Go For It           USA              M
# 4                            1      Go For It           USA              M
# ...                        ...            ...           ...            ...
# 70746                        3   Mystery Sale        Mexico              S
# 70747                        2   Mystery Sale        Mexico              S
# 70748                        2   Mystery Sale        Mexico              S
# 70749                        2   Mystery Sale        Mexico              S
# 70750                        2   Mystery Sale        Mexico              S
#
#       gender  ...  grocery_sqft frozen_sqft meat_sqft coffee_bar video_store  \
# 0          F  ...       22271.0      3561.0    2374.0          1           0
# 1          F  ...       22271.0      3561.0    2374.0          1           0
# 2          F  ...       22271.0      3561.0    2374.0          1           0
# 3          F  ...       22271.0      3561.0    2374.0          1           0
# 4          F  ...       22271.0      3561.0    2374.0          1           0
# ...      ...  ...           ...         ...       ...        ...         ...
# 70746      M  ...       15012.0      5751.0    3834.0          1           0
# 70747      M  ...       15012.0      5751.0    3834.0          1           0
# 70748      F  ...       15012.0      5751.0    3834.0          1           0
# 70749      F  ...       15012.0      5751.0    3834.0          1           0
# 70750      F  ...       15012.0      5751.0    3834.0          1           0
#
#        salad_bar prepared_food  florist      media_type    cost
# 0              0             0        0           Radio  228.19
# 1              0             0        0           Radio  228.19
# 2              0             0        0           Radio  228.19
# 3              0             0        0           Radio  228.19
# 4              0             0        0           Radio  228.19
# ...          ...           ...      ...             ...     ...
# 70746          0             0        0  Street Handout  728.89
# 70747          0             0        0  Street Handout  728.89
# 70748          0             0        0  Street Handout  728.89
# 70749          0             0        0  Street Handout  728.89
# 70750          0             0        0  Street Handout  728.89
#
# [70751 rows x 39 columns]

# %%
import time

def get_file_name(folderName, version):
  timestr = time.strftime("%Y%m%d%H%M%S")
  file_name = 'cac_'+folderName+'_'+timestr+'_'+version+'.csv'

  return file_name

# %%
filename = get_file_name('merged','001')
CAC.to_csv(filename)
